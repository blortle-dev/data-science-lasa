# %% [markdown]
# <a href="https://colab.research.google.com/github/blortle-dev/data-science-lasa/blob/main/Unit%208/Unit8ExercisesSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 8 Exercises: The Art of BART
#
# These exercises are grouped into two parts:
#
# - Questions on the nature of decision trees, random forests, and BART models
# - An oppurtunity to practice implementing and analyzing a BART model.
#
# Enjoy!

# %% [markdown]
# ## Bartian Theory

# %% [markdown]
# **Task1**:
#
# Draw a decision tree--on a physical piece of paper--that predicts how many calories you burn in a day, using time you spent exercising that day (in minutes) as a predictor.
#
# To help you understand what you're doing with this tree, seperately create an x/y plot with time exercising as x, and calories burned as y.
#
# If this seems to easy, then add another variable or two (type of exercise?), and/or increase the depth of your tree.
#
# You do not have to show me or turn in your tree to earn credit for this question, although I would like to see your drawing.

# %% [markdown]
# **Task2**:
#
# What is a decision tree? How do they work?

# %% [markdown]
# **Task3**:
#
# What does the "depth" of a decision tree mean?
#
# How do I know if a tree is too deep, or not deep enough?

# %% [markdown]
# **Task4:**
#
# How are BART models similar and different from a decision tree?

# %% [markdown]
# **Task5**:
#
# Why would we use a BART model instead of a decision tree?

# %% [markdown]
# ## Bartian Penguins

# %% [markdown]
# **Task6**:
#
# Create a BART model that uses flipper length, bill depth, and bill length to predict body mass in penguins, and make a ppc to check its fit
#
# Code for loading the data is below. You'll need to do everything else yourself.
#
# Remember to use my notes as a reference, and to copy and paste from them when it makes sense to.
#
# Oh, and try a normal likelihood.

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import seaborn as sns

# %%
# !pip install pymc-bart
# !pip install preliz

import pymc_bart as pmb
import preliz as pz
# Out:
# Collecting pymc-bart
#   Downloading pymc_bart-0.9.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting pymc<=5.20.1,>=5.16.2 (from pymc-bart)
#   Downloading pymc-5.20.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: arviz>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from pymc-bart) (0.21.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from pymc-bart) (0.60.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pymc-bart) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pymc-bart) (2.0.2)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (75.1.0)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (1.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (24.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (2.2.2)
# Requirement already satisfied: xarray>=2022.6.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (2025.1.2)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (1.6.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (4.12.2)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.18.0->pymc-bart) (0.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pymc-bart) (2.8.2)
# Requirement already satisfied: cachetools>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from pymc<=5.20.1,>=5.16.2->pymc-bart) (5.5.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pymc<=5.20.1,>=5.16.2->pymc-bart) (3.1.1)
# Collecting pytensor<2.28,>=2.26.1 (from pymc<=5.20.1,>=5.16.2->pymc-bart)
#   Downloading pytensor-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.11/dist-packages (from pymc<=5.20.1,>=5.16.2->pymc-bart) (13.9.4)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from pymc<=5.20.1,>=5.16.2->pymc-bart) (3.6.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->pymc-bart) (0.43.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from h5netcdf>=1.0.2->arviz>=0.18.0->pymc-bart) (3.13.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->arviz>=0.18.0->pymc-bart) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->arviz>=0.18.0->pymc-bart) (2025.1)
# Collecting numpy (from pymc-bart)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.15 in /usr/local/lib/python3.11/dist-packages (from pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (3.18.0)
# Requirement already satisfied: etuples in /usr/local/lib/python3.11/dist-packages (from pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (0.3.9)
# Requirement already satisfied: logical-unification in /usr/local/lib/python3.11/dist-packages (from pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (0.4.6)
# Requirement already satisfied: miniKanren in /usr/local/lib/python3.11/dist-packages (from pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (1.0.3)
# Requirement already satisfied: cons in /usr/local/lib/python3.11/dist-packages (from pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (0.4.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pymc-bart) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (0.1.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from logical-unification->pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (0.12.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from logical-unification->pytensor<2.28,>=2.26.1->pymc<=5.20.1,>=5.16.2->pymc-bart) (1.0.0)
# Downloading pymc_bart-0.9.0-py3-none-any.whl (31 kB)
# Downloading pymc-5.20.1-py3-none-any.whl (518 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 kB 16.7 MB/s eta 0:00:00
# Downloading pytensor-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 73.8 MB/s eta 0:00:00
# Installing collected packages: numpy, pytensor, pymc, pymc-bart
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pytensor
#     Found existing installation: pytensor 2.28.3
#     Uninstalling pytensor-2.28.3:
#       Successfully uninstalled pytensor-2.28.3
#   Attempting uninstall: pymc
#     Found existing installation: pymc 5.21.1
#     Uninstalling pymc-5.21.1:
#       Successfully uninstalled pymc-5.21.1
# Successfully installed numpy-1.26.4 pymc-5.20.1 pymc-bart-0.9.0 pytensor-2.27.1
# Collecting preliz
#   Downloading preliz-0.16.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.11/dist-packages (from preliz) (3.10.0)
# Requirement already satisfied: numba>=0.59 in /usr/local/lib/python3.11/dist-packages (from preliz) (0.60.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from preliz) (1.26.4)
# Requirement already satisfied: scipy<1.15,>=1.10 in /usr/local/lib/python3.11/dist-packages (from preliz) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7->preliz) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59->preliz) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7->preliz) (1.17.0)
# Downloading preliz-0.16.0-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 9.7 MB/s eta 0:00:00
# Installing collected packages: preliz
# Successfully installed preliz-0.16.0

# %%
#drop the incomplete rows from the data
url="https://raw.githubusercontent.com/thedarredondo/data-science-fundamentals/main/Data/penguins.csv"
penguins = pd.read_csv(url).dropna()

# %%
features = ["flipper_length", "bill_length", "bill_depth"]

X = penguins[features].to_numpy()
Y = penguins["body_mass"].to_numpy()

# %%
with pm.Model() as model_octps:
    s = pm.HalfNormal('s',1000)
    μ_ = pmb.BART("μ_", X, np.log(Y), m=50)
    μ = pm.Deterministic("μ",pm.math.exp(μ_))
    y = pm.Gamma("y", mu=μ, sigma=s,  observed=Y)
    idata_octps = pm.sample(compute_convergence_checks=False)
# Out:
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(-1.0)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp8xhav9r3/m8731756e50cee8e37acdac0b3dd2bc4ff97fca825a9b5af952811749616879ca.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp8xhav9r3/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp8xhav9r3/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
#
#
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(2)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpwdkps1ol/mc112f768f4d13e66ba4b8754215d292ea6da177816644c0ec397a46f231f6581.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpwdkps1ol/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpwdkps1ol/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_pkohbc1l
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_wb7cerp8
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(-1.0)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp9a2fpf2a/m8731756e50cee8e37acdac0b3dd2bc4ff97fca825a9b5af952811749616879ca.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp9a2fpf2a/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp9a2fpf2a/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
#
#
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(2)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp9qnw77eg/mc112f768f4d13e66ba4b8754215d292ea6da177816644c0ec397a46f231f6581.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp9qnw77eg/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp9qnw77eg/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_ve9flszw
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_43v111tk
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(-1.0)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpvzh_3a54/m8731756e50cee8e37acdac0b3dd2bc4ff97fca825a9b5af952811749616879ca.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpvzh_3a54/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpvzh_3a54/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
#
#
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(2)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpgiak69im/mc112f768f4d13e66ba4b8754215d292ea6da177816644c0ec397a46f231f6581.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpgiak69im/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpgiak69im/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_l2amtdw3
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_oss7xz0t
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: Cast{float32}(1000)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpzlrn79nw/m3065a1c6e613110a7a17adec6cf9796a0b8318e8223a3d5c6fb6d52a60faaa2b.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpzlrn79nw/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpzlrn79nw/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
#
#
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(1.4189121719466673)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp0mi7jhku/m3a950411050b810943c3042fc90477f763dda1abaf0cf4e92bcc0194f8dc7e70.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp0mi7jhku/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp0mi7jhku/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_898vt7x4
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_19wuet2v
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: Cast{float64}(1000)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpl77f337t/mb3c4f09dfbddec9be42c78405656f3ed5b2ce47050c523b443b10f9e45374264.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpl77f337t/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpl77f337t/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
#
#
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(1.4189121719466673)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
# ...
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmp68x7rqil/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
#
#
# ERROR:pytensor.graph.rewriting.basic:Rewrite failure due to: constant_folding
# ERROR:pytensor.graph.rewriting.basic:node: ExpandDims{axis=0}(1.4189121719466673)
# ERROR:pytensor.graph.rewriting.basic:TRACEBACK:
# ERROR:pytensor.graph.rewriting.basic:Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     return False
#                ^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1173, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/tensor/rewriting/basic.py", line 1122, in unconditional_constant_folding
#     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 119, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/op.py", line 84, in make_c_thunk
#     outputs = cl.make_thunk(
#               ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1185, in make_thunk
#     init_tasks, tasks = self.get_init_tasks()
#
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1102, in __compile__
#     output_storage = tuple(output_storage)
#                     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1626, in cthunk_factory
#     # Set compute_map as None as clinker do not support lazy evaluation
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 1250, in module_from_key
#     module = lnk.compile_cmodule(location)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/basic.py", line 1527, in compile_cmodule
#     # We want to compute the code without the lock
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py", line 2676, in compile_str
#     raise CompileError(
# pytensor.link.c.exceptions.CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpipex_czy/m3a950411050b810943c3042fc90477f763dda1abaf0cf4e92bcc0194f8dc7e70.so /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpipex_czy/mod.cpp -lpython3.11
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/tmpipex_czy/mod.cpp:5:10: fatal error: numpy/arrayobject.h: No such file or directory
#     5 | #include <numpy/arrayobject.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_xn3o8h56
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_19wj28ho
#
# You can find the C code in this temporary file: /tmp/pytensor_compilation_error_e9e3vx5v
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pytensor/link/c/lazylinker_c.py in <module>
#      65         if version != actual_version:
# ---> 66             raise ImportError(
#      67                 "Version check of the existing lazylinker compiled file."
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.212, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pytensor/link/c/lazylinker_c.py in <module>
#      86             if version != actual_version:
# ---> 87                 raise ImportError(
#      88                     "Version check of the existing lazylinker compiled file."
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.212, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# <ipython-input-5-e4208c40fee7> in <cell line: 0>()
#       4     μ = pm.Deterministic("μ",pm.math.exp(μ_))
#       5     y = pm.Gamma("y", mu=μ, sigma=s,  observed=Y)
# ----> 6     idata_octps = pm.sample(compute_convergence_checks=False)
#
# /usr/local/lib/python3.11/dist-packages/pymc/sampling/mcmc.py in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, compile_kwargs, **kwargs)
#     845     else:
#     846         # Get initial points
# --> 847         ipfns = make_initial_point_fns_per_chain(
#     848             model=model,
#     849             overrides=initvals,
#
# /usr/local/lib/python3.11/dist-packages/pymc/initial_point.py in make_initial_point_fns_per_chain(model, overrides, jitter_rvs, chains)
#      99         # Only one function compilation is needed.
#     100         ipfns = [
# --> 101             make_initial_point_fn(
#     102                 model=model,
#     103                 overrides=overrides,
#
# /usr/local/lib/python3.11/dist-packages/pymc/initial_point.py in make_initial_point_fn(model, overrides, jitter_rvs, default_strategy, return_transformed)
#     168     # when calling the final seeded function
#     169     initial_values = replace_rng_nodes(initial_values)
# --> 170     func = compile(inputs=[], outputs=initial_values, mode=pytensor.compile.mode.FAST_COMPILE)
#     171
#     172     varnames = []
#
# /usr/local/lib/python3.11/dist-packages/pymc/pytensorf.py in compile(inputs, outputs, random_seed, mode, **kwargs)
#     945     if inputs is None:
#     946         inputs = []
# --> 947
#     948     outs = makeiter(outputs)
#     949     fg = FunctionGraph(outputs=outs, clone=False)
#
# /usr/local/lib/python3.11/dist-packages/pytensor/compile/function/__init__.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, trust_input)
#     330             profile=profile,
#     331             output_keys=output_keys,
# --> 332         )
#     333     return fn
#
# /usr/local/lib/python3.11/dist-packages/pytensor/compile/function/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys, fgraph, trust_input)
#     470         name=name,
#     471         profile=profile,
# --> 472         on_unused_input=on_unused_input,
#     473         output_keys=output_keys,
#     474         fgraph=fgraph,
#
# /usr/local/lib/python3.11/dist-packages/pytensor/compile/function/types.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys, fgraph, trust_input)
#    1831                     "documentation or use an In instance)"
#    1832                 )
# -> 1833         elif isinstance(input[0], SymbolicInput):
#    1834             if len(input) == 1:
#    1835                 return input[0]
#
# /usr/local/lib/python3.11/dist-packages/pytensor/compile/function/types.py in create(self, input_storage, storage_map)
#    1715     mode : descriptive string or Mode instance
#    1716         Default of None means to use `config.mode` (see below for descriptive
# -> 1717         string list).
#    1718     name : str
#    1719         An optional name for this function. If used, the profile mode will print the
#
# /usr/local/lib/python3.11/dist-packages/pytensor/link/basic.py in make_thunk(self, input_storage, output_storage, storage_map, **kwargs)
#     243         **kwargs,
#     244     ) -> tuple["BasicThunkType", "InputStorageType", "OutputStorageType"]:
# --> 245         return self.make_all(
#     246             input_storage=input_storage,
#     247             output_storage=output_storage,
#
# /usr/local/lib/python3.11/dist-packages/pytensor/link/vm.py in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1283             post_thunk_clear = None
#    1284
# -> 1285         vm = self.make_vm(
#    1286             order,
#    1287             thunks,
#
# /usr/local/lib/python3.11/dist-packages/pytensor/link/vm.py in make_vm(self, nodes, thunks, input_storage, output_storage, storage_map, post_thunk_clear, computed, compute_map, updated_vars)
#    1011
#    1012         try:
# -> 1013             from pytensor.link.c.cvm import CVM
#    1014         except (MissingGXX, ImportError):
#    1015             CVM = None
#
# /usr/local/lib/python3.11/dist-packages/pytensor/link/c/cvm.py in <module>
#      11             "lazylinker will not be imported if pytensor.config.cxx is not set."
#      12         )
# ---> 13     from pytensor.link.c.lazylinker_c import CLazyLinker
#      14
#      15     class CVM(CLazyLinker, VM):
#
# /usr/local/lib/python3.11/dist-packages/pytensor/link/c/lazylinker_c.py in <module>
#     120
#     121             args = GCC_compiler.compile_args()
# --> 122             GCC_compiler.compile_str(dirname, code, location=loc, preargs=args)
#     123             # Save version into the __init__.py file.
#     124             init_py = loc / "__init__.py"
#
# /usr/local/lib/python3.11/dist-packages/pytensor/link/c/cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2674             # difficult to read.
#    2675             # compile_stderr = compile_stderr.replace("\n", ". ")
# -> 2676             raise CompileError(
#    2677                 f"Compilation failed (return status={status}):\n{' '.join(cmd)}\n{compile_stderr}"
#    2678             )
#
# CompileError: Compilation failed (return status=1):
# /usr/bin/g++ -shared -g -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=broadwell -mmmx -mpopcnt -msse -msse2 -msse3 -mssse3 -msse4.1 -msse4.2 -mavx -mavx2 -mno-sse4a -mno-fma4 -mno-xop -mfma -mno-avx512f -mbmi -mbmi2 -maes -mpclmul -mno-avx512vl -mno-avx512bw -mno-avx512dq -mno-avx512cd -mno-avx512er -mno-avx512pf -mno-avx512vbmi -mno-avx512ifma -mno-avx5124vnniw -mno-avx5124fmaps -mno-avx512vpopcntdq -mno-avx512vbmi2 -mno-gfni -mno-vpclmulqdq -mno-avx512vnni -mno-avx512bitalg -mno-avx512bf16 -mno-avx512vp2intersect -mno-3dnow -madx -mabm -mno-cldemote -mno-clflushopt -mno-clwb -mno-clzero -mcx16 -mno-enqcmd -mf16c -mfsgsbase -mfxsr -mhle -msahf -mno-lwp -mlzcnt -mmovbe -mno-movdir64b -mno-movdiri -mno-mwaitx -mno-pconfig -mno-pku -mno-prefetchwt1 -mprfchw -mno-ptwrite -mno-rdpid -mrdrnd -mrdseed -mrtm -mno-serialize -mno-sgx -mno-sha -mno-shstk -mno-tbm -mno-tsxldtrk -mno-vaes -mno-waitpkg -mno-wbnoinvd -mxsave -mno-xsavec -mxsaveopt -mno-xsaves -mno-amx-tile -mno-amx-int8 -mno-amx-bf16 -mno-uintr -mno-hreset -mno-kl -mno-widekl -mno-avxvnni --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=56320 -mtune=broadwell -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/_core/include -I/usr/include/python3.11 -I/usr/local/lib/python3.11/dist-packages/pytensor/link/c/c_code -L/usr/lib/x86_64-linux-gnu -L/usr/lib -fvisibility=hidden -o /root/.pytensor/comp...
# /root/.pytensor/compiledir_Linux-6.1.85+-x86_64-with-glibc2.35-x86_64-3.11.11-64/lazylinker_ext/mod.cpp:7:10: fatal error: numpy/npy_3kcompat.h: No such file or directory
#     7 | #include "numpy/npy_3kcompat.h"
#       |          ^~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.

# %% [markdown]
# **Task7**:
#
# Plot flipper length versus body mass,
#
# and then plot the posterior predictve from the model over the data.
# You're going to copy paste the plotting code from the notes, fyi.

# %% [markdown]
# **Task8**:
#
# Interpret the plot above in context. Do you think it captures the true association between flipper length and body mass in penguins? Why or why not? Make sure to reference specific things you see in the plot.

# %% [markdown]
# **Task9**:
#
# Create partial depnedence plots (pdps), individual conditional expectation (ice) plots, and a variable importance plot for the BARTpenguin model.

# %% [markdown]
# **Task10**:
#
# Using the above plots, make an argument about which variable(s) is/are most important in predicting body mass in penguins.
#
# What is the relationship for each variable to body mass, when you take the other variables into account?
#
# Is that relationship complicated by interactions between variables? How do you know?
#
# Make sure to reference specific things you see in each plot, to justify your decisions and comments.
